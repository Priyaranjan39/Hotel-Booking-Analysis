# %% [markdown]
# # **Project Name**    - Hotel Booking Analysis

# %% [markdown]
# ##### **Project Type**    - EDA
# ##### **Contribution**    - Individual

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## Introduction
#
# The hospitality industry is one of the most competitive markets, where understanding customer behavior and booking patterns can significantly improve business performance. This project focuses on analyzing hotel booking data to uncover meaningful insights that can help hoteliers optimize occupancy rates, reduce cancellations, improve guest satisfaction, and increase revenue. The main objective was to explore booking trends, cancellation behavior, and seasonal effects on demand, while also identifying key factors influencing customer decisions.
#
# ## Data and Methodology
#
# The analysis was performed on a real-world dataset containing approximately 120,000 booking records from a city hotel and a resort hotel. The dataset included 32 features, such as ( hotel, is_canceled, lead_time, arrival_date_year, arrival_date_month, stays_in_weekend_nights, stays_in_week_nights, adults, children, babies, market_segment, distribution_channel, is_repeated_guest, previous_cancellations, and adr ).
#
# The data was cleaned and preprocessed to handle missing values, duplicates, and inconsistent entries. Exploratory Data Analysis (EDA) was performed using Python libraries such as Pandas, Matplotlib, and Seaborn. Various visualizations such as bar charts, line plots, histograms, heatmaps, and pairplots were used to clearly identify booking patterns, seasonal demand, cancellation trends, and correlations among variables. These visual representations allowed for a deeper and more intuitive understanding of the dataset.
#
# ## Key Findings and Insights
#
# The analysis revealed several interesting insights:
#
# 1. Booking Distribution: Bar plots showed that city hotels received more bookings compared to resort hotels, highlighting higher demand in urban areas. However, visualizations of stay duration confirmed that resort hotels had longer average stays, suggesting leisure travelers prefer resorts for extended vacations.
#
# 2. Seasonal Trends: Line plots and time-series visualizations indicated clear seasonal patterns, with peak bookings during summer months and holiday seasons. Off-peak seasons showed lower occupancy rates, suggesting the need for targeted discounts or promotional offers during these periods.
#
# 3. Cancellation Patterns: Heatmaps and scatterplots highlighted a strong link between longer lead times (the time between booking and arrival) and higher cancellation rates, especially for city hotels. This indicates that guests who book far in advance are more likely to cancel their plans.
#
# 4. Market Segment Insights: Visualizations of booking channels showed that most bookings came from online travel agents, underlining the importance of digital platforms in the hospitality industry. However, these channels also had higher cancellation rates compared to direct bookings, suggesting hotels could benefit from strengthening direct booking channels through loyalty programs or special incentives.
#
# 5. Guest Demographics: Plots of customer type distributions revealed that families and groups tended to book resort hotels, while solo and business travelers preferred city hotels. Additionally, visualizations of cancellations by country indicated that guests from certain regions had a higher tendency to cancel, which could guide region-specific strategies.
#
# 6. Room Preferences: Visualizations comparing requested vs. assigned room types showed mismatches that were linked with customer dissatisfaction and higher cancellations. Ensuring proper room allocation can therefore enhance guest experience and reduce booking cancellations.
#
# ## Conclusion and Recommendations
#
# This project highlights that hotel bookings are influenced by seasonality, booking channels, lead time, and customer type. The high cancellation rates, particularly from online travel agents and long-lead bookings, pose a challenge for revenue management.
#
# To address these issues, hotels can adopt the following strategies:
#
#   * Cancellation rates rise as the price does. In order to prevent cancellations of reservations, hotels could work on their pricing strategies and try to lower the rates of specific hotels based on locations. They can also provide some discounts to the consumers.
#
#   * As the ratio of the cancellation and not cancellation of the resort hotel is higher in the resort hotel than the city hotels. So the hotels should provide a reasonable discount on the room prices on weekends or on holidays
#
#   * In the month of January, hotels can start campaigns or marketing with a reasonable amount to increase their revenue as the cancellation is the highest in this month.
#
#   * They can also increase the quality of their hotels and their services mainly in Portugal to reduce the cancellation rate.
#
#
# marketing campaigns.
#
# Overall, this analysis provides a deeper understanding of hotel booking behavior and offers practical solutions for improving occupancy, reducing cancellations, and enhancing customer satisfaction. By leveraging data-driven strategies, hotels can strengthen their market position and improve long-term profitability.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Priyaranjan39

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# In recent years, City Hotel and Resort Hotel have seen high cancellation rates. Each hotel is now dealing with a number of issues as a result, including fewer revenues and less than ideal hotel room use. Consequently, lowering cancellation rates is both hotel's primary goal in order to increase their efficiency in generating revenue, and for us to offer through business advice to address ths problem.
# The analysis of hotel booking cancellation as well as other factors that have no bearing on their business and yearly revenue generation are the main topics of this report.

# %% [markdown]
# #### **Define Your Business Objective?**

# %% [markdown]
# My primary objective is to identify and quantify the key factors that influence hotel booking cancellations and revenue generation to reduce cancellation rates, optimize pricing strategies, and maximize overall profitability for the hotel industry.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
from google.colab import drive

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
drive.mount('/content/drive')
dataset=pd.read_csv('/content/drive/MyDrive/dataset/Hotel Bookings.csv')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Dataset First View

# %%
# Dataset First Look
dataset.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
# Analyze cancellation rates by market segment for both hotel types
market_segment_analysis = dataset.groupby(["hotel", "market_segment"])["is_canceled"].mean() * 100

# Analyze cancellation rates by deposit type for both hotel types
deposit_type_analysis = dataset.groupby(["hotel", "deposit_type"])["is_canceled"].mean().unstack() * 100

market_segment_analysis
# , deposit_type_analysis
# Out:
# hotel         market_segment
# City Hotel    Aviation           21.940928
#               Complementary      11.808118
#               Corporate          21.466845
#               Direct             17.331364
#               Groups             68.858676
#               Offline TA/TO      42.831552
#               Online TA          37.398059
#               Undefined         100.000000
# Resort Hotel  Complementary      16.417910
#               Corporate          15.201386
#               Direct             13.480731
#               Groups             42.392049
#               Offline TA/TO      15.230193
#               Online TA          35.241694
# Name: is_canceled, dtype: float64

# %%
# Compare lead time for canceled bookings in both hotel types
lead_time_analysis = dataset.groupby(["hotel", "is_canceled"])["lead_time"].mean().unstack()
lead_time_analysis
# Out:
# is_canceled           0           1
# hotel
# City Hotel    80.702734  150.281222
# Resort Hotel  78.837618  128.680543

# %%
dataset.groupby('hotel')['is_canceled'].mean()
# Out:
# hotel
# City Hotel      0.417270
# Resort Hotel    0.277634
# Name: is_canceled, dtype: float64

# %%
print(dataset.groupby('hotel')['is_canceled'].mean())
plt.figure(figsize=(10,5))
sns.countplot(x=dataset['hotel'],hue=dataset['is_canceled'])
plt.show()
# Out:
# hotel
# City Hotel      0.417270
# Resort Hotel    0.277634
# Name: is_canceled, dtype: float64

# %%
reservation_count= dataset['is_canceled'].value_counts()
reservation_count.index=['Not canceled','Canceled']
plt.figure(figsize=(10,8))
plt.pie(reservation_count.values, labels=reservation_count.index, autopct='%1.2f%%',shadow=True,startangle=90, labeldistance = 1.2, explode = [0.05,0.05],textprops={'size': 'larger'})
plt.title('Reservation Status', bbox={'facecolor':'1', 'pad':3} ,fontsize=15)
plt.legend(title='Hotel',loc='upper right')
plt.show()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Dataset Rows & Columns count
print("Number of rows in the dataset:",dataset.shape[0])
print("Number of columns in the dataset:",dataset.shape[1])
# Out:
# Number of rows in the dataset: 119390
# Number of columns in the dataset: 32

# %%
dataset.hotel.value_counts()
# Out:
# hotel
# City Hotel      79330
# Resort Hotel    40060
# Name: count, dtype: int64

# %%
dataset[dataset['hotel']=='City Hotel'].hotel.value_counts()
# Out:
# hotel
# City Hotel    79330
# Name: count, dtype: int64

# %%
aa=dataset.hotel=='City Hotel'
aa.sum()
# Out:
# np.int64(79330)

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Info
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119390 entries, 0 to 119389
# Data columns (total 32 columns):
#  #   Column                          Non-Null Count   Dtype
# ---  ------                          --------------   -----
#  0   hotel                           119390 non-null  object
#  1   is_canceled                     119390 non-null  int64
#  2   lead_time                       119390 non-null  int64
#  3   arrival_date_year               119390 non-null  int64
#  4   arrival_date_month              119390 non-null  object
#  5   arrival_date_week_number        119390 non-null  int64
#  6   arrival_date_day_of_month       119390 non-null  int64
#  7   stays_in_weekend_nights         119390 non-null  int64
#  8   stays_in_week_nights            119390 non-null  int64
#  9   adults                          119390 non-null  int64
#  10  children                        119386 non-null  float64
#  11  babies                          119390 non-null  int64
# ...

# %% [markdown]
# #### Duplicate Values

# %%
# Dataset Duplicate Value Count
print(f"No. of Duplicate rows are {dataset.duplicated().sum()}")
# Out:
# No. of Duplicate rows are 31994

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Missing Values/Null Values Count
dataset.isnull().sum()
# Out:
# hotel                                  0
# is_canceled                            0
# lead_time                              0
# arrival_date_year                      0
# arrival_date_month                     0
# arrival_date_week_number               0
# arrival_date_day_of_month              0
# stays_in_weekend_nights                0
# stays_in_week_nights                   0
# adults                                 0
# children                               4
# babies                                 0
# meal                                   0
# country                              488
# market_segment                         0
# distribution_channel                   0
# is_repeated_guest                      0
# previous_cancellations                 0
# previous_bookings_not_canceled         0
# reserved_room_type                     0
# assigned_room_type                     0
# booking_changes                        0
# deposit_type                           0
# ...

# %% [markdown]
# This dataset contains missing values in multiple columns. The columns with missing values are children, country, agent, and company.
#
# The column children has 4 missing values.
#
# The column country has 488 missing values.
#
# The column agent has 16,340 missing values.
#
# The column company has 112,593 missing values.

# %%
# Visualizing the missing values
dataset.isnull().sum().plot(kind='bar')
# Out:
# <Axes: >

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# We know the following info from the hotel booking dataset are:
#
# **Number of Rows:** The dataset contains 119,390 entries or rows.
#
# **Number of Columns:** There are 32 columns in the dataset, each representing different attributes or features related to hotel bookings.
#
# **Data Types:** The dataset contains a mix of data types, including integers (int64), floats (float64), and objects (object). This suggests that the dataset includes both numerical and categorical variables.
#
# **Duplicates Rows:** The dataset contains 31,994 duplicate entries, indicating potential replication of information across various records.
#
# **Missing Values:** While the majority of columns contain complete data, several columns exhibit notable numbers of missing values. Specifically, the company column shows a substantial count of 112,593 missing values, while the agent column has 16,340 missing values. Additionally, the country and children columns contain 488 and 4 missing values, respectively.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
dataset.columns
# Out:
# Index(['hotel', 'is_canceled', 'lead_time', 'arrival_date_year',
#        'arrival_date_month', 'arrival_date_week_number',
#        'arrival_date_day_of_month', 'stays_in_weekend_nights',
#        'stays_in_week_nights', 'adults', 'children', 'babies', 'meal',
#        'country', 'market_segment', 'distribution_channel',
#        'is_repeated_guest', 'previous_cancellations',
#        'previous_bookings_not_canceled', 'reserved_room_type',
#        'assigned_room_type', 'booking_changes', 'deposit_type', 'agent',
#        'company', 'days_in_waiting_list', 'customer_type', 'adr',
#        'required_car_parking_spaces', 'total_of_special_requests',
#        'reservation_status', 'reservation_status_date'],
#       dtype='object')

# %%
# Dataset Describe
dataset.describe()
# Out:
#          is_canceled      lead_time  arrival_date_year  \
# count  119390.000000  119390.000000      119390.000000
# mean        0.370416     104.011416        2016.156554
# std         0.482918     106.863097           0.707476
# min         0.000000       0.000000        2015.000000
# 25%         0.000000      18.000000        2016.000000
# 50%         0.000000      69.000000        2016.000000
# 75%         1.000000     160.000000        2017.000000
# max         1.000000     737.000000        2017.000000
#
#        arrival_date_week_number  arrival_date_day_of_month  \
# count             119390.000000              119390.000000
# mean                  27.165173                  15.798241
# std                   13.605138                   8.780829
# min                    1.000000                   1.000000
# 25%                   16.000000                   8.000000
# 50%                   28.000000                  16.000000
# ...

# %% [markdown]
# ### Variables Description

# %% [markdown]
# **hotel:** Type of hotel (e.g., resort hotel, city hotel).
#
# **is_canceled:** Binary indicator of whether the booking was canceled (1 = canceled, 0 = not canceled).
#
# **lead_time:** Number of days between booking date and arrival date.
#
# **arrival_date_year:** Year of arrival date.
#
# **arrival_date_month:** Month of arrival date.
#
# **arrival_date_week_number:** Week number of arrival date.
#
# **arrival_date_day_of_month:** Day of the month of arrival date.
#
# **stays_in_weekend_nights:** Number of weekend nights stayed.
#
# **stays_in_week_nights:** Number of week nights stayed.
#
# **adults:** Number of adults included in the booking.
#
# **children:** Number of children included in the booking.
#
# **babies:** Number of babies included in the booking.
#
# **meal:** Type of meal booked (e.g., Undefined/SC – no meal package; BB – Bed & Breakfast).
#
# **country:** Country of origin.
#
# **market_segment:** Market segment designation (e.g., Online Travel Agents, Offline Travel Agents).
#
# **distribution_channel:** Booking distribution channel (e.g., Direct, Corporate) is_repeated_guest: Binary indicator of whether the guest is a repeated guest (1 = yes, 0 = no).
#
# **previous_cancellations:** Number of previous cancellations by the guest.
#
# **previous_bookings_not_canceled:** Number of previous bookings not canceled by the guest.
#
# **reserved_room_type:** Code of room type reserved.
#
# **assigned_room_type:** Code of room type assigned.
#
# **booking_changes:** Number of changes made to the booking deposit_type: Type of deposit made for the booking (e.g., No Deposit, Non Refund, Refundable).
#
# **agent:** ID of the travel agency that made the booking.
#
# **company:** ID of the company/entity that made the booking.
#
# **days_in_waiting_list:** Number of days the booking was on the waiting list before confirmed.
#
# **customer_type:** Type of booking customer (e.g., Transient, Contract, Group).
#
# **adr:** Average Daily Rate (average rental income per paid occupied room).
#
# **required_car_parking_spaces:** Number of car parking spaces required by the guest.
#
# **total_of_special_requests:** Number of special requests made by the guest.
#
# **reservation_status:** Reservation status (e.g., Canceled, Check-Out).
#
# **reservation_status_date:** Date at which the reservation status was last updated.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
for i in dataset.columns.tolist():
  print("No. of unique values in ",i,"is",dataset[i].nunique(),".")
# Out:
# No. of unique values in  hotel is 2 .
# No. of unique values in  is_canceled is 2 .
# No. of unique values in  lead_time is 479 .
# No. of unique values in  arrival_date_year is 3 .
# No. of unique values in  arrival_date_month is 12 .
# No. of unique values in  arrival_date_week_number is 53 .
# No. of unique values in  arrival_date_day_of_month is 31 .
# No. of unique values in  stays_in_weekend_nights is 17 .
# No. of unique values in  stays_in_week_nights is 35 .
# No. of unique values in  adults is 14 .
# No. of unique values in  children is 5 .
# No. of unique values in  babies is 5 .
# No. of unique values in  meal is 5 .
# No. of unique values in  country is 177 .
# No. of unique values in  market_segment is 8 .
# No. of unique values in  distribution_channel is 5 .
# No. of unique values in  is_repeated_guest is 2 .
# No. of unique values in  previous_cancellations is 15 .
# No. of unique values in  previous_bookings_not_canceled is 73 .
# ...

# %%
# Check Unique Values for each variable.
dataset.nunique()
# Out:
# hotel                                2
# is_canceled                          2
# lead_time                          479
# arrival_date_year                    3
# arrival_date_month                  12
# arrival_date_week_number            53
# arrival_date_day_of_month           31
# stays_in_weekend_nights             17
# stays_in_week_nights                35
# adults                              14
# children                             5
# babies                               5
# meal                                 5
# country                            177
# market_segment                       8
# distribution_channel                 5
# is_repeated_guest                    2
# previous_cancellations              15
# previous_bookings_not_canceled      73
# reserved_room_type                  10
# assigned_room_type                  12
# booking_changes                     21
# deposit_type                         3
# agent                              333
# ...

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
hotel_booking_df=dataset.copy()

# %%
# removing duplicate rows
hotel_booking_df.drop_duplicates(inplace=True)
hotel_booking_df.reset_index(drop=True,inplace=True)
unique_rows=hotel_booking_df.shape[0]
print(f"No. of unique rows are {unique_rows}")
# Out:
# No. of unique rows are 87396

# %%
# Write your code to make your dataset analysis ready.
# Count the null value for each columns in descending order.
hotel_booking_df.isnull().sum().sort_values(ascending=False).head()
# Out:
# company               82137
# agent                 12193
# country                 452
# children                  4
# arrival_date_month        0
# dtype: int64

# %%
# Finding the percentage of null values present in each columns
hotel_null_percentage=((hotel_booking_df.isnull().sum()/hotel_booking_df.shape[0])*100).sort_values(ascending=False)
hotel_null_percentage.head()
# Out:
# company               93.982562
# agent                 13.951439
# country                0.517186
# children               0.004577
# arrival_date_month     0.000000
# dtype: float64

# %%
# Percentage of Null values in 'company' column is greater than 90 percent, so it would be nice to drop this column from hotel_booking_df dataframe
hotel_booking_df.drop(['company'],axis=1,inplace=True)
hotel_booking_df.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  \
# 0                        0                     0       2  ...
# ...

# %%
# filling the missing value of country columns
hotel_booking_df['country'].fillna('others',inplace=True)
print(f"No. of NULL values in country column is {hotel_booking_df['country'].isnull().sum()}.")
# Out:
# No. of NULL values in country column is 0.

# %%
# finding the skewness value of columns 'agent' and 'children' before filling the missing values.
hotel_booking_df[['agent','children']].skew().rename('skew value')
# Out:
# agent       0.890404
# children    3.463573
# Name: skew value, dtype: float64

# %%
# filling the missing value of 'agent' and 'children' column by there median values, because there skewness values are greater than 0.5
hotel_booking_df.fillna({'agent':hotel_booking_df['agent'].median(),'children':hotel_booking_df['children'].median()},inplace=True)
print(f"No. of NULL values in agent column is {hotel_booking_df['agent'].isnull().sum()}.")
print(f"No. of NULL values in children column is {hotel_booking_df['children'].isnull().sum()}.")
# Out:
# No. of NULL values in agent column is 0.
# No. of NULL values in children column is 0.

# %%
# Now checking the NULL values for each columns.
hotel_booking_df.isnull().sum().sort_values(ascending=False).head()
# Out:
# hotel                 0
# is_canceled           0
# lead_time             0
# arrival_date_year     0
# arrival_date_month    0
# dtype: int64

# %%
# Checking the shape of hotel_booking_df dataframe after droping the duplicate values
hotel_booking_df.shape
# Out:
# (87396, 31)

# %%
# Droping the rows where columns ( 'adults', 'children', and 'babies') is equal to zero. becasue it simply means no bookings were made.
hotel_booking_df=hotel_booking_df[hotel_booking_df['adults']+hotel_booking_df['children']+hotel_booking_df['babies']!=0]

# %%
# replacing the month name with month number
hotel_booking_df['arrival_date_month']=hotel_booking_df['arrival_date_month'].replace({'January':'01','February':'02','March':'03','April':'04','May':'05','June':'06','July':'07','August':'08','September':'09','October':'10','November':'11','December':'12'})

# %%
# Creating a column named arrival date by concat and converting arrival_date_year, arrival_date_month and arrival_date_day_of_month.
hotel_booking_df['arrival_date_str'] = hotel_booking_df['arrival_date_year'].astype(str) + '-' + hotel_booking_df['arrival_date_month'].astype(str) + '-' + hotel_booking_df['arrival_date_day_of_month'].astype(str)
hotel_booking_df['arrival_date'] = pd.to_datetime(hotel_booking_df['arrival_date_str'])
hotel_booking_df['arrival_date'].head()
# Out:
# 0   2015-07-01
# 1   2015-07-01
# 2   2015-07-01
# 3   2015-07-01
# 4   2015-07-01
# Name: arrival_date, dtype: datetime64[ns]

# %%
hotel_booking_df.shape
# Out:
# (87230, 33)

# %%
# Data type of column 'reservation_status_date' is object, therefore I convert it to date type.
hotel_booking_df['reservation_status_date']= pd.to_datetime(hotel_booking_df['reservation_status_date'])

# %%
# Now checking the data type of column 'reservation_status_date'
print(hotel_booking_df['reservation_status_date'].dtype)
# Out:
# datetime64[ns]

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# * Removed duplicate rows from the hotel_booking DataFrame.
#
# * Dropped the Company column due to a high number of null values.
#
# * Filled the missing values in the agent column and children column with there median because there skewness value greater than (0.5) .
#
# * Filled missing values in the country column with 'other' to handle missing categorical data.
#
# * Droping the rows where columns ( 'adults', 'children', and 'babies') is equal to zero. becasue it simply means that no bookings were made.
#
# * Replacing the month name with month number.
#
# * Created a column named arrival date by concat and converting arrival_date_year, arrival_date_month and arrival_date_day_of_month.
#
# * Data type of column 'reservation_status_date' is object, therefore I convert it to date type.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1 visualization code
# Pie Chart for most preferred hotel (Univariate)
country_count=hotel_booking_df['hotel'].value_counts()
plt.figure(figsize=(10,8))
plt.pie(country_count.values,labels=country_count.index, autopct='%1.2f%%',shadow=True,startangle=90, labeldistance = 1.1,explode=[0.05,0.05],textprops={'size':'larger'})
plt.title('Most Preferred Hotel',bbox={'facecolor':'1','pad':3})
plt.legend()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I pick pie chart because it show proportions or percentages of a whole, especially with a small number of categories. It helps to compare parts to the total and highlight major vs. minor contributions and
# It's easy to explain the percentage comparison through area covered in a circle with different colors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pie chart indicates that City Hotel is the most preferred choice among guests, receiving the highest number of bookings. 61.07% of guests prefer City Hotel, while only 38.93% have opted for Resort Hotel.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, the gained insights can create a positive business impact by helping optimize marketing efforts and improve Resort Hotel’s appeal to attract more guests.

# %% [markdown]
# Yes, the lower preference for Resort Hotel (38.9%) indicates a potential risk.
# It may face lower revenue and underutilized resources due to fewer bookings.
# This could impact brand perception and competitiveness in the market.
# Addressing these gaps through marketing and service improvements is essential.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2 visualization code
# Pie Chart for reservation status (Univariate)
reservation_count= hotel_booking_df['is_canceled'].value_counts()
reservation_count.index=['Not canceled','Canceled']
plt.figure(figsize=(10,8))
plt.pie(reservation_count.values, labels=reservation_count.index, autopct='%1.2f%%',shadow=True,startangle=90, labeldistance = 1.2, explode = [0.05,0.05],textprops={'size': 'larger'})
plt.title('Reservation Status', bbox={'facecolor':'1', 'pad':3} ,fontsize=15)
plt.legend(title='Hotel',loc='upper right')
plt.show()

# %%
kk= hotel_booking_df['adr'].mean()
kk
# Out:
# np.float64(106.51803072337499)

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is used here because it effectively displays a part-to-whole relationship. It instantly shows the proportion of hotel reservations that are 'Canceled' versus 'Not canceled' out of the total number of bookings, making the comparison clear and easy to grasp.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The main insight is that while most customers (72.48%) keep their reservations, a very significant portion (27.52%) end up canceling. This means that more than one out of every four bookings is canceled, which is quite a high number for a hotel business.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, absolutely. Knowing that over 27% of reservations are canceled helps the business take action. They can now investigate the reasons for cancellations and create strategies, like better booking policies or special offers, to reduce this number and increase their revenue.
#
# Yes, the high cancellation rate of 27.52% is a direct indicator of a problem that hurts business growth. This figure represents a major loss of expected income for the hotel. It also makes it difficult to manage room availability and staffing effectively, which costs the business money.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3 visualization code
repeat_guest_count=hotel_booking_df['is_repeated_guest'].value_counts()
repeat_guest_count.index=['Not Repeated','Repeated']
plt.figure(figsize=(10,8))
plt.pie(repeat_guest_count.values,labels=repeat_guest_count.index, autopct='%1.2f%%',shadow=True,startangle=45, labeldistance = 1.1, explode = [0.05,0.05],textprops={'size': 'larger'})
plt.title('Repeated Guest' , bbox={'facecolor':'1', 'pad':3})
plt.legend(title='Guest')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is the perfect choice here because it's designed to show parts of a whole. It instantly gives a clear visual of the proportion of repeat guests versus new guests, making it easy to understand the percentages at a single glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The main insight is that the business has a very low customer retention rate. An overwhelming 96% of guests are one-time visitors, while a tiny fraction, less than 4%, are returning customers, which is a critical issue to address.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Absolutely. Identifying this low loyalty is the first step to fixing it. The business can now implement strategies like loyalty programs or special offers for returning guests, which can significantly boost revenue and create a more stable customer base.
#
# Yes, this chart points directly to a factor that hurts growth. Relying on 96% new customers is an expensive and unstable model because constantly acquiring new clients costs much more than retaining old ones. This high "churn" can erode profits and make sustainable growth very difficult.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4 visualization code
print(hotel_booking_df.groupby('hotel')['is_canceled'].mean())
plt.figure(figsize=(10,5))
sns.countplot(x=hotel_booking_df['hotel'],hue=hotel_booking_df['is_canceled'])
plt.title('Reservation Status in different hotels',bbox={'facecolor':'1','pad':3})
plt.legend(['Not Canceled','Canceled'])
plt.show()
# Out:
# hotel
# City Hotel      0.300991
# Resort Hotel    0.234833
# Name: is_canceled, dtype: float64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is perfect here because we are comparing quantities across different groups. It clearly shows the count of canceled and non-canceled bookings side-by-side for both the Resort and City hotels, making it very easy to compare them.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that City Hotels get far more bookings than Resort Hotels, but they also have a significantly higher number of cancellations. Proportionally, it also appears that City Hotels have a higher cancellation rate compared to Resort Hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, absolutely. Knowing that City Hotels are the main source of cancellations allows the business to investigate the reasons why. By addressing these specific issues, they can reduce cancellations and increase their revenue.
#
# Yes, the large number of cancellations, especially at the City Hotel, points to a negative trend. Each cancellation represents lost revenue, and if this high rate continues without being addressed, it will directly harm profitability and hinder the company's growth.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5 visualization code
plt.figure(figsize=(10,5))
sns.countplot(x=hotel_booking_df['hotel'],hue=hotel_booking_df['is_repeated_guest'])
plt.title('Repeated Guest in different hotels',bbox={'facecolor':'1','pad':3})
plt.legend(['Not Repeated','Repeated'])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This type of bar chart is perfect for this situation because it clearly compares the number of new ("Not Repeated") and returning ("Repeated") guests for each hotel type. The side-by-side bars make the massive difference between the two groups immediately obvious.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most striking insight is that both hotels have an extremely low number of repeat guests compared to new ones. While City Hotels have more guests overall, both types struggle significantly with bringing customers back for a second stay.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this information is very valuable. By realizing how few customers return, the business can focus on creating loyalty programs, improving the guest experience, or offering incentives for future stays. Increasing repeat business is a great way to boost revenue.
#
# Yes, the very small number of repeat guests is a strong indicator of a potential problem that could lead to negative growth. A business that isn't retaining its customers has to constantly spend more money on marketing to attract new ones, which is expensive and not sustainable long-term.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6 visualization code
plt.figure(figsize=(10,5))
sns.histplot(data=hotel_booking_df,x='children',hue='hotel',element='step',bins=10)
plt.title('Reservation status of Children in different hotel ',bbox={'facecolor':'1','pad':3})
plt.legend(hotel_booking_df['hotel'].unique())
plt.show()
hotel_booking_df['children'].value_counts()
# Out:
# children
# 0.0     78866
# 1.0      4695
# 2.0      3593
# 3.0        75
# 10.0        1
# Name: count, dtype: int64

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is the best choice here because it shows the distribution of a numerical value—the number of children. By stacking the bars for each hotel type, we can easily compare how many bookings with children each hotel gets, all in one clear visual.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The clearest insight is that the vast majority of guests at both hotels travel with no children. However, for the small number of guests who do travel with children, Resort Hotels appear to be a more popular choice than City Hotels.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this is very useful. It suggests Resort Hotels can attract more families by enhancing kid-friendly amenities and marketing. City Hotels, on the other hand, can focus their efforts and budget on catering to their main audience: adults and solo travelers.
#
# This chart highlights a missed opportunity for City Hotels, which could limit growth. By failing to attract the family travel market, they are losing out on a significant source of revenue. If family travel becomes more popular, their inability to capture this segment could put them at a disadvantage.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 8 visualization code
country_count=hotel_booking_df.loc[hotel_booking_df['is_canceled']==1,'country'].value_counts().sort_values(ascending=False).head(10)
plt.figure(figsize=(10,8))
plt.pie(country_count.values,labels=country_count.index, autopct='%1.2f%%',startangle=45, labeldistance = 1.1)
plt.title('Reservation Canceled status of top 10 Country',bbox={'facecolor':'1', 'pad':3})
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is an excellent choice here because it clearly shows the proportion of cancellations coming from each country relative to the total. It makes it immediately obvious which countries are the biggest contributors, allowing you to see the breakdown at a glance.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most significant insight is that guests from Portugal (PRT) account for nearly half (49.52%) of all cancellations among the top 10 countries. This is disproportionately high compared to other countries like the UK (GBR) and Spain (ESP), which are the next largest contributors.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this information is extremely valuable. Instead of applying a broad strategy, the business can now focus its resources specifically on understanding the reasons for the high cancellation rate in Portugal. Solving this single, major issue could lead to a massive reduction in overall cancellations and a significant boost in revenue.
#
#
# Yes, the heavy concentration of cancellations from a single country (Portugal) is a major red flag that negatively impacts growth. This points to a severe, localized problem that is causing a substantial loss of income. If this issue isn't resolved, it will continue to be a major drain on the company's profitability and stability.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 9 visualization code
x=hotel_booking_df.copy()
x['is_canceled']=x['is_canceled'].replace({0:'Not Canceled',1:'Canceled'})
plt.figure(figsize=(10,5))
sns.boxplot(x='lead_time',y='is_canceled',data=x)
plt.title('Lead Time and Cancellation',bbox={'facecolor':'1','pad':3})
plt.xlabel('Lead Time')
plt.ylabel('Cancellation')
plt.show()

# %%
hotel_lead_time= hotel_booking_df.groupby(["hotel", "is_canceled"])["lead_time"].mean().reset_index()
hotel_lead_time['is_canceled'].replace({0:'Not Canceled',1:'Canceled'},inplace=True)
hotel_lead_time
# we clearly see that more lead time cause more cancelletion number.
# Out:
#           hotel   is_canceled   lead_time
# 0    City Hotel  Not Canceled   67.517388
# 1    City Hotel      Canceled  101.657499
# 2  Resort Hotel  Not Canceled   74.009738
# 3  Resort Hotel      Canceled  113.944444

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart, called a box plot, is perfect for comparing the distribution of a numerical value (Lead Time) across two different categories (Canceled vs. Not Canceled). It clearly shows how the range and average booking times differ between guests who cancel and those who don't.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The main insight is that bookings with a longer lead time are much more likely to be canceled. The "Canceled" box is shifted further to the right, showing that the median time between booking and arrival is significantly higher for reservations that get canceled.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this is very actionable. The hotel can use this information to create targeted policies, such as requiring deposits for bookings made far in advance or sending strategic reminders to these guests. This can help secure revenue and reduce the overall cancellation rate.
#
# Yes, the trend shown is a direct source of lost revenue, which harms growth. Each long-lead-time booking that gets canceled represents a room that was held off the market, potentially for months. This predictable loss of sales is a consistent drain on profitability.

# %% [markdown]
# #### Chart - 9

# %%
# Chart - 10 visualization code
plt.figure(figsize=(10,5))
sns.countplot(data=hotel_booking_df,x='meal',palette='Set2')
plt.title('Prefered Meal',bbox={'facecolor':'1','pad':3})
plt.legend(hotel_booking_df['meal'].unique(),title='Meal')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is the ideal choice here because it's the clearest way to show and compare the counts for different categories. It makes it incredibly easy to see which meal option is the most popular just by comparing the heights of the bars.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most obvious insight is that the Bed & Breakfast (BB) meal plan is overwhelmingly the most popular choice among guests. Half Board (HB) and Self-Catering (SC) are the next most common choices, while Full Board (FB) is rarely selected.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this is very useful for business operations. Knowing that breakfast is the most important meal allows the hotel to focus on perfecting its breakfast service and managing food inventory and kitchen staff more effectively, which can save costs and improve guest satisfaction.
#
# Yes, the extremely low popularity of the Full Board (FB) package indicates a missed opportunity that could limit growth. This suggests that the hotel's all-inclusive meal offerings are not appealing or well-priced, causing them to lose out on potential revenue from guests who might otherwise spend more on food.

# %% [markdown]
# #### Chart - 10

# %%
# Chart - 3 visualization code
resort_hotel=hotel_booking_df[hotel_booking_df['hotel']=='Resort Hotel'].groupby('reservation_status_date')[['adr']].mean()
city_hotel=hotel_booking_df[hotel_booking_df['hotel']=='City Hotel'].groupby('reservation_status_date')[['adr']].mean()
plt.figure(figsize=(15,5))
plt.title('Average Daily Rate in City and Resort Hotel', bbox={'facecolor':'1', 'pad':3})
plt.xlabel('Reservation Status Date')
plt.ylabel('Average Daily Rate')
plt.plot(resort_hotel.index,resort_hotel['adr'],label = 'Resort Hotel')
plt.plot(city_hotel.index,city_hotel['adr'],label = 'City Hotel')
plt.legend(fontsize=10,loc='lower right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# I chose a line chart because it's the best tool for showing how something changes over time. It makes it really easy to see the trends, peaks, and dips in the average daily room rates for both City and Resort hotels over the years and compare them directly.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# City Hotel (orange line) has a steady and stable increase in ADR(Average Daily Rate).
# Resort Hotel (blue line) shows high volatility, with significant fluctuations.
# Seasonal patterns are visible, affecting both hotels, but Resort Hotel is more impacted.
# Recent trends (2017) indicate higher ADR for both hotels, but Resort Hotel remains more unstable.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, definitely. By understanding these seasonal trends, hotels can use dynamic pricing to their advantage. They can increase prices during peak seasons to maximize profit and offer discounts during slow periods to attract more guests and keep occupancy high.

# %% [markdown]
# Negative growth is observed during off-peak seasons when ADR significantly declines due to reduced demand. Additionally, price fluctuations and competition between City and Resort hotels indicate market saturation, leading to lower profitability.

# %% [markdown]
# #### Chart - 11

# %%
# Chart - 11 visualization code
plt.figure(figsize=(10,10))
sns.histplot(data=hotel_booking_df,x='market_segment',hue='hotel',palette='Set2',element='step')
plt.title('Market Segment',bbox={'facecolor':'1','pad':3})
plt.legend(hotel_booking_df['hotel'].unique(),title='Market Segment')
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This type of chart is perfect for comparing the total number of bookings from different sources (like 'Online' or 'Direct'). By stacking the colors for Resort and City hotels, it also clearly shows which hotel type is more popular within each source, giving us two layers of information at once.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most important insight is that the vast majority of bookings for both hotels come from Online Travel Agents (Online TA/TO). While direct bookings and offline agents are also sources of business, the hotels are heavily reliant on online booking platforms to fill their rooms.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this is very useful. It tells the business to maintain strong partnerships with their online travel agents. It also highlights a great opportunity to increase profits by creating marketing campaigns that encourage more customers to book directly, as direct bookings don't require paying commission fees.
#
# Yes, being overly dependent on one channel, like Online Travel Agents, is a significant risk that can harm growth. The high commission fees paid to these agents reduce profit on every booking, and if that channel's performance ever drops, the hotel's revenue would be severely impacted due to a lack of diverse booking sources.

# %% [markdown]
# #### Chart - 12

# %%
# Chart - 12 visualization code
plt.figure(figsize=(10,5))
sns.countplot(data=hotel_booking_df, x='reserved_room_type',hue='hotel',palette='rainbow',order=hotel_booking_df['reserved_room_type'].value_counts().index)
plt.xlabel('Reserved Room Type')
plt.title('Reserved Room Type in Different Hotels',bbox={'facecolor':'1','pad':3})
plt.legend(hotel_booking_df['hotel'].unique(),title='Hotel', loc='upper right')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This type of chart, a grouped bar chart, is perfect because it allows for easy comparison on two levels. We can quickly see which room type is most popular overall, and the side-by-side bars let us directly compare the demand for each room between the Resort and City hotels.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The most important insight is that Room Type 'A' is overwhelmingly the most popular, especially for the City Hotel, which has a massive number of bookings for it. Room Type 'D' is the second most common choice, while several other room types are booked very rarely.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, absolutely. This helps the hotels with revenue management; they can optimize the pricing for their most popular rooms ('A' and 'D'). It also informs them about which room types are less desirable, which could be used for promotional offers or considered for renovation in the future.
#
# Yes, the extremely low booking counts for room types like 'B', 'C', 'H', and 'L' point to a problem. These rooms cost money to maintain but generate very little income. This inefficient use of assets can drag down overall profitability and hinder the hotel's financial growth.

# %% [markdown]
# #### Chart - 13

# %%
# Chart - 13 visualization code
a=hotel_booking_df.groupby(['arrival_date_month','hotel'])['adr'].mean().reset_index().copy()
a['arrival_date_month'].replace({'01':'January','02':'February','03':'March','04':'April','05':'May','06':'June','07':'July','08':'August','09':'September','10':'October','11':'November','12':'December'},inplace=True)
plt.figure(figsize=(10,5))
plt.xticks(rotation=30)
sns.lineplot(data=a,x='arrival_date_month',y='adr',hue='hotel')
plt.xlabel('Average Daily Rate')
plt.legend(title='Hotel')
plt.title('Average Daily Rate (ADR) across each Months',bbox={'facecolor':'1','pad':3})
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is the best choice for this data because it's designed to show how a value, like the average room price, changes over a continuous period of time. It makes it very easy to see and compare the pricing trends of both hotel types across the months of the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The clearest insight is that the Resort Hotel's pricing is extremely seasonal, with a massive spike in the summer months and very low prices in the off-season. In contrast, the City Hotel's prices are much more stable throughout the year, though they also peak slightly in the spring and summer.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this information is crucial for revenue management. It confirms when the hotels should implement peak pricing to maximize profit and when they should offer discounts to attract guests during slow periods. This allows for a smarter, more dynamic pricing strategy to boost yearly income.
#
# Yes, the Resort Hotel's heavy dependence on a short summer season is a significant business risk. If anything were to disrupt that peak period (like bad weather or an economic downturn), it could cripple their revenue for the entire year, posing a serious threat to consistent growth.

# %% [markdown]
# #### Chart - 14

# %%
plt.figure(figsize = (10,4))
sns.countplot(x = hotel_booking_df['reservation_status_date'].dt.month, hue = hotel_booking_df['is_canceled'], palette = 'flare')
plt.legend(['Not Cancelled', 'Cancelled'])
plt.title('Reservation status with respect to months for city and resort hotels')
plt.ylabel('Reservation count')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This grouped bar chart is an excellent choice because it clearly compares two different categories (Cancelled vs. Not Cancelled) for each month. It allows for a quick visual check of both the total bookings and the number of cancellations side-by-side. This makes it easy to understand the relationship between them throughout the year.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The busiest month for hotels is August, with the highest number of successful stays. However, the summer months also see a high volume of cancellations. The period with the least activity, for both bookings and cancellations, appears to be around the end of the year (November and December).

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, definitely. Hotels can use this information to plan for the busy August peak by increasing staff and adjusting prices to maximize profit. They can also create special deals and marketing campaigns for slower months like November to attract more guests and maintain steady business.
#
# The consistently high number of cancellations across all months is a major concern that could lead to negative growth. This represents a significant loss of guaranteed income and makes it hard to manage room availability. If not addressed, this constant loss of revenue can seriously impact the hotel's profitability.

# %% [markdown]
# #### Chart - 15 - Correlation Heatmap

# %%
# Correlation Heatmap visualization code

# Selecting the columns which data type is 'integer' and 'float'
numeric_df = hotel_booking_df.select_dtypes(include=['float64', 'int64'])

# Calculate correlation matrix
corr_matrix = numeric_df.corr()

# Plot heatmap
plt.figure(figsize=(12, 10))
sns.heatmap(corr_matrix, annot=True,cmap='Reds', linecolor='black',fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart, called a correlation heatmap, is the best way to see the relationship between all the numerical variables in a dataset at a single glance. The color-coding makes it incredibly easy to quickly spot which factors have a strong or weak connection to each other, which would be hard to see in a simple table of numbers.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This heatmap reveals how different factors are connected to booking cancellations and each other.
#
# It shows that there's a slight tendency for cancellations to increase as the **lead_time** (the gap between booking and arrival) gets longer.
#
# Interestingly, guests who have **special_requests** or need **car_parking_spaces** are slightly less likely to cancel their bookings.
#
# We also see some common-sense relationships, like a moderate link between the number of weekend nights and week nights a person stays.
#
# However, the main takeaway is that most factors do not have a strong, direct impact on each other.

# %% [markdown]
# #### Chart - 16 - Pair Plot

# %%
+# Pair Plot visualization code

numeric_columns = ['lead_time', 'is_canceled', 'stays_in_weekend_nights', 'stays_in_week_nights', 'adults',
                   'children', 'babies', 'previous_cancellations', 'previous_bookings_not_canceled',
                   'booking_changes', 'days_in_waiting_list', 'adr', 'required_car_parking_spaces',
                   'total_of_special_requests' ]
numeric_data = hotel_booking_df[numeric_columns]

plt.figure(figsize=(18,16))
# sns.set_style('whitegrid')
sns.pairplot(data = numeric_data , corner = True)
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart, known as a pair plot, is a fantastic tool for getting a quick overview of all the numerical data at once. It's like a master chart that combines two types of visuals: it shows the individual distribution of each factor (in the histograms on the diagonal) and also creates a scatter plot to show the relationship between every possible pair of factors.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# This pairplot gives a complete picture of how all the numeric variables relate to each other. Most variables show weak or scattered relationships, meaning they don’t strongly influence one another. A few pairs show clear positive or negative trends, which hints at possible correlations worth exploring further. The diagonal plots show that some variables are normally distributed while others are skewed, suggesting the dataset has a mix of patterns.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# To achieve the business objective, the client should focus on the following strategies:
#
#
#
# ### **1. Reduce High Cancellation Rates (27.5%)**
#
#   Since longer lead-time bookings are more likely to be canceled:
#
#   * Introduce non-refundable or partially refundable rates with discounts.
#
#   * Add reminder communications before check-in date.
#
#   * Implement flexible date change policies rather than cancellations.
#
#   * Use cancellation prediction models to identify high-risk bookings.
#
#
#
# ### **2. Increase Repeat Customers (Only 3.86%)**
#
# Low repeat bookings show a big business opportunity:
#
# * Start a loyalty points or membership program.
#
# * Provide special returning guest discounts.
#
# * Collect and use customer preferences for personalization.
#
# * Automate post-stay engagement (emails, offers, feedback requests).
#
#
# ### **3. Increase Revenue**
# Insights show: City hotel earns more in May, Resort hotel earns more in July–August, Majority of guests choose room type A and BB meal plan.
#
# * Use dynamic pricing based on peak and low seasons.
#
# * Upsell upgrades, meal plans, and add-on services.
#
# * Offer bundled packages to increase per-booking value.
#
# * Adjust Room Type A prices upward during high demand.
#
# ### **4. Improve Room & Offering Utilization**
#
# Insights show: Room Type A and BB plans are most popular.
#
# * Increase price slightly during peak seasons.
#
# * Promote other room types with upgrades or discounts.
#
# * Add premium BB variations to grow meal-related revenue.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# **These are some conclusions that we get after performing EDA.**
#
# 1. City hotel is mostly preferred hotel by guests.
#
# 2. Percentage of repeated guest is less which is 3.86%.
#
# 3. Cancellation rate is 27.52 %.
#
# 4. Bookings with a longer lead time are much more likely to be canceled.
#
# 5. Mostly preferred food type is BBtype food.
#
# 6. Room type A is mostly preferred room type.
#
# 7.  The vast majority of guests at both hotels travel with no children.
#
# 8. Most guests are coming from Portugal.
#
# 9. TA/TO distribution channel is mostly used and percentage is 79.13%.
#
# 10. For year 2016 highest bookings were there for both city and resort hotel.
#
# 11. City Hotel generates more revenue in May and Resort Hotel generates more revenue between July and August.
#
# 12. The busiest month for hotels is August, with the highest number of successful stays. However, the summer months also see a high volume of cancellations.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
